# %% [markdown]
# # PYTHON LIST

# %% [markdown]
# - It is commonly used data type that represents an ordered, mutable(modifiable) and iterable sequence of elements
# -
# List are used to strore collections of items, and these items can be of any data type, including numbers, strings, or even othe lists.
# - Lists are defined using square brackets [ ] and elemts are seperated by comma(,)s).

# %% [markdown]
# ### CREATION OF LIST

# %%
empty_list = []
names =["vinod","raju","ramesh","suresh"]
mixedlist = [1,2,"vinod", None,222.22]

print(type(empty_list))
print(type(names))
print(type(mixedlist))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %% [markdown]
# ### Access List Elements

# %% [markdown]
# - In Python, Lists are orderd and each item in a list is associated with a number. The number is known as a list index.
# - The index of the first element is 0, second element is 1 and so on.
# - Python allows negitive indexing for its sequences.
# - The index of -1 referes to the last item, -2 to the second last item and so on.

# %%
# Positive indexing
language = ["Python", "Swift", "C++", "C"]
print(language[0])
print(language[2])
# Out:
# Python
# C++

# %%
# Negitive indexing
names = ["raju", "mahesh", "vinod", "ganni"]
print(names[-1])
print(names[-4])
# Out:
# ganni
# raju

# %% [markdown]
# ### Slicing of a List

# %% [markdown]
# - In Python, it is possible to access a portion of a list using the slicing Operator:

# %%
my_list = ['E','t','a','c','k','e','g','A','h','o','j','s','M','o','u','n','i','y']
print(my_list[5:10])
print(my_list[:15])
print(my_list[4:])
print(my_list[:])
print(my_list[-10:-1])
# Out:
# ['e', 'g', 'A', 'h', 'o']
# ['E', 't', 'a', 'c', 'k', 'e', 'g', 'A', 'h', 'o', 'j', 's', 'M', 'o', 'u']
# ['k', 'e', 'g', 'A', 'h', 'o', 'j', 's', 'M', 'o', 'u', 'n', 'i', 'y']
# ['E', 't', 'a', 'c', 'k', 'e', 'g', 'A', 'h', 'o', 'j', 's', 'M', 'o', 'u', 'n', 'i', 'y']
# ['h', 'o', 'j', 's', 'M', 'o', 'u', 'n', 'i']

# %% [markdown]
# ### List Operations

# %% [markdown]
# #### List Contain Two types of Operations.
#
# - Concatenation
# - Repetition

# %% [markdown]
# ## 1. Concatenation

# %%
# Adding Two lists 
a = [1,2,3,4]
b = [1,4,5,6,3,9]
c = a + b
print(c)
# Out:
# [1, 2, 3, 4, 1, 4, 5, 6, 3, 9]

# %% [markdown]
# # 2.Repetition

# %%
# Repete the values at multiple times
a = [3,5,2,1,8,5,0,9]
b = a * 14
print(b)
# Out:
# [3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9, 3, 5, 2, 1, 8, 5, 0, 9]

# %% [markdown]
# #### Change List items

# %% [markdown]
#  To change the values of a specific item, refer to the index number.

# %%
my_list = ["vinod","pavan","jagan"]
print(my_list)
my_list[2]= "naresh"
print(my_list)
# Out:
# ['vinod', 'pavan', 'jagan']
# ['vinod', 'pavan', 'naresh']

# %%
vowels = ['a','b','c','d','f']
print(vowels)
vowels[1:5] = ['e','i','o','u']
print(vowels)
# Out:
# ['a', 'b', 'c', 'd', 'f']
# ['a', 'e', 'i', 'o', 'u']

# %% [markdown]
# # LIST METHODS

# %% [markdown]
# ![image.png](attachment:63a57213-dfee-4e09-a9e0-46f3a15975b7.png)

# %% [markdown]
# ### 1. append( ):
#   To add an item to the end of the list, use the append() method:

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# ### 2. extend( ):
# To append elements from another list to the current list, use the extend() method.

# %%
thislist = ["apple", "banana", "cherry"]
fruits = ["mango", "pineapple", "papaya"]
thislist.extend(fruits)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %% [markdown]
# ### 3. insert( ):
# To insert a list item at a specified index or position, use the insert() method.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(1, "orange")
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %% [markdown]
# ### 4. remove( ):
# Removes the first occurance of a value, The remove() method removes the specified item.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# ### 5. pop( ):
# The pop() method removes the specified index, Removes and returns an elements at a specified index.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# ### 6. index( ):
# Returns the index of the first occurance of a value

# %%
names = ["vinod","raji","pavan","jagan","charan","naresh","teja"]
index = names.index("raji")
print(index)
# Out:
# 1

# %% [markdown]
# ### 7. count( ):
# Returns the number of occurances of a value

# %%
numbers = [1,2,3,2,4,2,6,7,9,6,0,2,3,4]
count = numbers.count(2)
print(count)
# Out:
# 4

# %% [markdown]
# ### 8. sort( ):
# Sorts the list in a ascending order

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %% [markdown]
# ### 9. reverse( ):
# Reverses the order of elements in the list

# %%
my_string = "Hello, World!"
reversed_string = my_string[::-1]
print(reversed_string)
# Out:
# !dlroW ,olleH

# %%
numbers = [6,0,2,6,4,8,6,0]
numbers.reverse()
print(numbers)
# Out:
# [0, 6, 8, 4, 6, 2, 0, 6]

# %% [markdown]
# ### 10. copy( ):
# Returns a shallow copy of the list.

# %%
my_list = [1, 2, 3, 5]
new_list = my_list.copy()
print(new_list)
# Out:
# [1, 2, 3, 5]

# %% [markdown]
# ### 11. del( ):
# The del keyword also removes the specified index:

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %% [markdown]
# ### 12. clear( ):
# The clear( ) method empties the list. The list still remains, but it has no content.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []
