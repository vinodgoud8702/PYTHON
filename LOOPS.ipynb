# %% [markdown]
# # PYTHON LOOPS
# ### Loops in Python

# %% [markdown]
# In programming, the loops are the constructs that repeatedly execute a piece of code based on the conditions. These are useful in many situations like going through every element of a list, doing an operation on a range of values, etc.
#
# There are two types of loops in Python
# - these are FOR and WHILE loops. Both of them work by following the below steps:
#
# 1. Check the condition
# 2. If True, execute the body of the block under it. And update the iterator/ the value on which the condition is checked.
# 3. If False, come out of the loop

# %% [markdown]
# ## While Loop in Python

# %% [markdown]
# While loops execute a set of lines of code iteratively till a condition is satisfied.
# Once the condition results in False, it stops execution, and the part of the program after the loop starts executing.

# %% [markdown]
# - The syntax of the while loop is :
#
# while condition:
#     statement(s)

# %% [markdown]
# Here,
#
# - A while loop evaluates the condition
#
# - If the condition evaluates to True, the code inside the while loop is executed.
#
# - condition is evaluated again.
#
# - This process continues until the condition is False.
#
# - When condition evaluates to False, the loop stops.

# %% [markdown]
# ![image.png](attachment:8f9546fa-aefb-42bd-8788-22a7d0ab7e55.png)

# %%
#EXAMPLE 
count = 0
while count <= 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#2 
number = int(input('Enter a number: '))
while number != 0:
    print(f'You entered {number}.')
    number = int(input('Enter a number: '))

print('The end.')
# Out:
# Enter a number:  77
# You entered 77.
# Enter a number:  88
# You entered 88.
# Enter a number:  99
# You entered 99.
# Enter a number:  00
# The end.

# %%
total = 0
num = 1
while num <= 100:
    total += num
    num += 1
print("Sum of numbers from 1 to 100:", total)
# Out:
# Sum of numbers from 1 to 100: 5050

# %% [markdown]
# # For loop in python

# %% [markdown]
# The for loop is used for iterating over a sequence (that is either a list, tuple, dictionary, string, or range).
#
# The syntax of a for loop is:
#
# for val in sequence: # statement(s)
#
# Here, val accesses each item of the sequence on each iteration.
#
# The loop continues until we reach the last item in the sequence.

# %% [markdown]
# ![image.png](attachment:fd22f26a-179b-412e-9635-7040246cf7e3.png)

# %%
#1
language = 'Python'
for x in language:
    print(x)
# Out:
# P
# y
# t
# h
# o
# n

# %%
#2
fruits = ["apple", "banana", "cherry", "date"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry
# date

# %%
#3
numbers = [23, 45, 67, 12, 89, 54]
largest = numbers[0]
 
for num in numbers:
    if num > largest:
        largest = num
 
print("The largest number is:", largest)
# Out:
# The largest number is: 89
